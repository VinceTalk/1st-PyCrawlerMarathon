# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'

r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

columns = ['作者', '看板', '標題', '時間']

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
items = soup.findAll(True, {"class": re.compile(r'(r-ent|r-list-sep)')})
for item in range(len(items)):
    if 'r-list-sep' in items[item].attrs['class']:
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+items[item-1].a['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            print('作者: {}\n標題: {}\n時間: {}'.format(article[0], article[2], article[-1]))
        except:
            continue
# Out:
# 作者: NSYSUheng (Pain)
# 標題: [情報] Pippen：灰狼的隊友不喜歡Butler，因為他
# 時間: Fri Dec 13 21:04:50 2019

# %%
def GetFistPageInfo(url):
    r = requests.get(url)
    
    soup = BeautifulSoup(r.text, "html5lib")
    
    articles = []
    
    for d in soup.find_all(class_="title"):
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            articles.append(article)
        except:
            continue
    df = pd.DataFrame(articles, columns=columns)
    
    return df

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
GetFistPageInfo('https://www.ptt.cc/bbs/NBA/index1.html')
# Out:
#                              作者   看板                         標題  \
# 0                 Price (Price)  NBA    [轉錄]Lyotard 對於太陽板討論串的結論
# 1                 Price (Price)  NBA        [公告] 請停止一切關於本次活動的發言
# 2               Frankaze (神采風華)  NBA   [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 3               Frankaze (神采風華)  NBA                [轉錄]再轉一篇好文來
# 4                 Price (Price)  NBA           [轉錄][情報] 夏洛特山貓系列
# 5                 Price (Price)  NBA   [轉錄]Re: [心得] 真是受不了糗爺....
# 6                 Price (Price)  NBA            [轉錄]總冠軍賽NO.2觀後感
# 7   AmuroNamie (原來太嗨真的會失眠^___^)  NBA       [心得] Rasheed Wallace
# 8                  toptree (  )  NBA                    掌控球賽的男人
# 9            skchang (3EB板開板囉！)  NBA        [閒聊] 說說2004季後賽名場面回顧
# 10                   shineup ()  NBA     [心得] 其實說穿了 就是活塞的防守太可怕了
# 11                    cOvi (喵~)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 12               ykshih (￼N￼Ns)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 13              Frankaze (神采風華)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 14                Price (Price)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 15              Frankaze (神采風華)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 16          star1 (第一次魔術表演不算成功)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 17              coldspring (笑笑)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 18                 airbear (地圖)  NBA  Re: Kobe is frustrated...
# 19            pennykidd (andre)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
#
#                           時間
# 0   Sun May 16 01:54:33 2004
# 1   Mon May 24 00:43:00 2004
# 2   Tue Jun  8 01:16:45 2004
# 3   Tue Jun  8 09:02:23 2004
# 4   Thu Jun 10 00:39:35 2004
# 5   Thu Jun 10 00:51:35 2004
# 6   Thu Jun 10 12:05:07 2004
# 7   Fri Jun 11 15:06:09 2004
# 8   Sat Jun 12 07:13:04 2004
# 9   Sat Jun 12 13:21:49 2004
# 10  Sat Jun 12 13:12:47 2004
# 11  Sat Jun 12 16:43:07 2004
# 12  Sat Jun 12 17:26:37 2004
# 13  Sat Jun 12 18:34:46 2004
# 14  Mon Jun 14 02:18:52 2004
# 15  Mon Jun 14 02:34:33 2004
# 16  Mon Jun 14 07:16:30 2004
# 17  Mon Jun 14 09:24:57 2004
# 18  Mon Jun 14 12:56:14 2004
# 19  Mon Jun 14 22:07:01 2004

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
GetFistPageInfo('https://www.ptt.cc/bbs/MobileComm/index.html')
# Out:
#                                   作者          看板  \
# 0                    BGWalker (BG行者)  MobileComm
# 1                        Kay731 (K少)  MobileComm
# 2                     NTUMEDRX (AUD)  MobileComm
# 3              nokia95 ((人生就是該積沙成塔))  MobileComm
# 4                olmtw (支持htc，支持台灣貨)  MobileComm
# 5                       j7893 (> <")  MobileComm
# 6                        solomn (九米)  MobileComm
# 7                    leadra (leadra)  MobileComm
# 8              weifenglish (Weifeng)  MobileComm
# 9                    nehemiah (amen)  MobileComm
# 10                     Komasan (摳媽桑)  MobileComm
# 11                        espreso ()  MobileComm
# 12                        bolin (小寶)  MobileComm
# 13     hvariables (Speculative Male)  MobileComm
# 14  paul40807 ([email protected] 最高)  MobileComm
# 15               nk950357 (nk950357)  MobileComm
# 16                      FeRin (咬著秒針)  MobileComm
# 17                  HamalAri (哈馬‧阿里)  MobileComm
# 18       bigbowl ( Gathering Storm。)  MobileComm
#
#                                 標題                        時間
# 0               [問題] 三星保固內換電池的一些問題  Fri Dec 13 18:45:16 2019
# 1            [閒聊] SAMSUNG A40 簡易開箱  Fri Dec 13 19:16:28 2019
# 2                [問題] 台灣之星188續約想解約  Fri Dec 13 19:24:32 2019
# 3      [討論] 雙11 PC24 realme xt預購贈點  Fri Dec 13 19:42:10 2019
# 4           [新聞] 蘋果最新收購的公司專精於銳利化照片  Fri Dec 13 19:46:02 2019
# 5                          中華公務員方案  Fri Dec 13 20:00:50 2019
# 6         [問題] 小型無線耳機都長的像AirPods白色  Fri Dec 13 20:14:10 2019
# 7               [問機]Zen4泡水要再買一支什麼好  Fri Dec 13 21:14:14 2019
# 8                   [情報] 台灣之星電銷299  Fri Dec 13 21:44:41 2019
# 9                      [問題] NP遠傳問題  Fri Dec 13 21:50:13 2019
# 10         [問機] 長輩用手機推薦 5K以上，10K以下  Fri Dec 13 22:19:54 2019
# 11        [心得] samsung a70螢幕炸裂維修心得  Fri Dec 13 22:25:38 2019
# 12       三星Note8 過保前第五次維修 更換螢幕及主機板  Fri Dec 13 22:40:55 2019
# 13  [新聞] 美中傳達成貿易協議 一支iPhone少課4500元  Fri Dec 13 22:49:02 2019
# 14       [情報] 3G要斷訊了? 3G執照到期相關情報整理  Wed Aug 15 02:49:50 2018
# 15     [公告] MobileComm板規 20190728版  Sat Aug 17 00:59:40 2019
# 16                  Re: [閒聊] 置底閒聊文  Sun Nov  3 22:33:58 2019
# 17   [閒聊] 各種價位的手機/平板列表(2019/11/12)  Tue Nov 12 22:51:42 2019
# 18         Fw: [公告] 請使用安全的連線方式連線本站  Sun Nov 24 21:30:26 2019
