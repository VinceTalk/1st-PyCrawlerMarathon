# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10969929825","type":"PullRequestReviewCommentEvent","actor":{"id":55024892,"login":"IvanKogut11","display_login":"IvanKogut11","gravatar_id":"","url":"https://api.github.com/users/IvanKogut11","avatar_url":"https://avatars.githubusercontent.com/u/55024892?"},"repo":{"id":62727275,"name":"kontur-courses/fluent-api","url":"https://api.github.com/repos/kontur-courses/fluent-api"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/kontur-courses/fluent-api/pulls/comments/351821233","pull_request_review_id":324336044,"id":351821233,"node_id":"MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1MTgyMTIzMw==","diff_hunk":"@@ -1,41 +1,154 @@\\n using System;\\n+using System.Collections;\\n+using System.Collections.Generic;\\n+using System.Globalization;\\n using System.Linq;\\n+using System.Linq.Expressions;\\n+using System.Reflection;\\n using System.Text;\\n \\n namespace ObjectPrinting\\n {\\n-    public class PrintingConfig<TOwner>\\n+    public class PrintingConfig<TOwner> :\\n+        IPrintingConfig<TOwner>\\n     {\\n+        private static readonly Type[] finalTypes = new Type[]\\n+        {\\n+            typeof(int), typeof(double), typeof(float), typeof(string),\\n+            typeof(DateTime), typeof(TimeSpan)\\n+        };\\n+        private readonly HashSet<object> propertiesInRecursion = new HashSet<object>();\\n+        private readonly HashSet<Type> excludedTypes = new HashSet<Type>();\\n+        private readonly HashSet<PropertyInfo> excludedProperties = new HashSet<PropertyInfo>();\\n+        private readonly Dictionary<PropertyInfo, int> maxLengthOfStringProperty =\\n+            new Dictionary<PropertyInfo, int>();\\r\\n+        private readonly Dictionary<Type, Func<object, string>> exactSerializationForType =\\n+            new Dictionary<Type, Func<object, string>>();\\n+        private readonly Dictionary<PropertyInfo, Func<object, string>> exactSerializationForProperty =\\n+            new Dictionary<PropertyInfo, Func<object, string>>();\\n+        private readonly Dictionary<Type, CultureInfo> numberTypesCultures =\\n+            new Dictionary<Type, CultureInfo>();\\n+\\n+        //��� ��� ������� ����� ���������, ����� ������ �� ������������\\n+        Dictionary<Type, Func<object, string>> IPrintingConfig<TOwner>.SerializationForType =>\\n+            exactSerializationForType;\\n+        Dictionary<PropertyInfo, Func<object, string>> IPrintingConfig<TOwner>.SerializationForProperty =>\\n+            exactSerializationForProperty;\\n+        Dictionary<Type, CultureInfo> IPrintingConfig<TOwner>.NumberTypesCultures => numberTypesCultures;\\n+        Dictionary<PropertyInfo, int> IPrintingConfig<TOwner>.MaxLengthOfStringProperty\\n+        {\\n+            get => maxLengthOfStringProperty;\\n+        }\\n+\\n         public string PrintToString(TOwner obj)\\n         {\\n             return PrintToString(obj, 0);\\n         }\\n \\n         private string PrintToString(object obj, int nestingLevel)\\n         {\\n-            //TODO apply configurations\\n-            if (obj == null)\\n+            if (obj == null)   \\n                 return \\"null\\" + Environment.NewLine;\\n-\\n-            var finalTypes = new[]\\n-            {\\n-                typeof(int), typeof(double), typeof(float), typeof(string),\\n-                typeof(DateTime), typeof(TimeSpan)\\n-            };\\n-            if (finalTypes.Contains(obj.GetType()))\\n-                return obj + Environment.NewLine;\\n-\\n+            propertiesInRecursion.Add(obj);\\n+            var type = obj.GetType();\\n+            if (excludedTypes.Contains(type))\\n+                return FinishWorkWithObjectAndReturnResult(obj, string.Empty);\\n+            if (finalTypes.Contains(type))\\n+                return FinishWorkWithObjectAndReturnResult(obj,\\n+                    ReturnSerializationOFFinalTypeObject(obj));\\n             var identation = new string(\'\\\\t\', nestingLevel + 1);\\n             var sb = ne ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10969929825',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 55024892,
#    'login': 'IvanKogut11',
#    'display_login': 'IvanKogut11',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IvanKogut11',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55024892?'},
#   'repo': {'id': 62727275,
#    'name': 'kontur-courses/fluent-api',
#    'url': 'https://api.github.com/repos/kontur-courses/fluent-api'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/comments/351821233',
#     'pull_request_review_id': 324336044,
#     'id': 351821233,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1MTgyMTIzMw==',
#     'diff_hunk': '@@ -1,41 +1,154 @@\n using System;\n+using System.Collections;\n+using System.Collections.Generic;\n+using System.Globalization;\n using System.Linq;\n+using System.Linq.Expressions;\n+using System.Reflection;\n using System.Text;\n \n namespace ObjectPrinting\n {\n-    public class PrintingConfig<TOwner>\n+    public class PrintingConfig<TOwner> :\n+        IPrintingConfig<TOwner>\n     {\n+        private static readonly Type[] finalTypes = new Type[]\n+        {\n+            typeof(int), typeof(double), typeof(float), typeof(string),\n+            typeof(DateTime), typeof(TimeSpan)\n+        };\n+        private readonly HashSet<object> propertiesInRecursion = new HashSet<object>();\n+        private readonly HashSet<Type> excludedTypes = new HashSet<Type>();\n+        private readonly HashSet<PropertyInfo> excludedProperties = new HashSet<PropertyInfo>();\n+        private readonly Dictionary<PropertyInfo, int> maxLengthOfStringProperty =\n+            new Dictionary<PropertyInfo, int>();\r\n+        private readonly Dictionary<Type, Func<object, string>> exactSerializationForType =\n+            new Dictionary<Type, Func<object, string>>();\n+        private readonly Dictionary<PropertyInfo, Func<object, string>> exactSerializationForProperty =\n+            new Dictionary<PropertyInfo, Func<object, string>>();\n+        private readonly Dictionary<Type, CultureInfo> numberTypesCultures =\n+            new Dictionary<Type, CultureInfo>();\n+\n+        //��� ��� ������� ����� ���������, ����� ������ �� ������������\n+        Dictionary<Type, Func<object, string>> IPrintingConfig<TOwner>.SerializationForType =>\n+            exactSerializationForType;\n+        Dictionary<PropertyInfo, Func<object, string>> IPrintingConfig<TOwner>.SerializationForProperty =>\n+            exactSerializationForProperty;\n+        Dictionary<Type, CultureInfo> IPrintingConfig<TOwner>.NumberTypesCultures => numberTypesCultures;\n+        Dictionary<PropertyInfo, int> IPrintingConfig<TOwner>.MaxLengthOfStringProperty\n+        {\n+            get => maxLengthOfStringProperty;\n+        }\n+\n         public string PrintToString(TOwner obj)\n         {\n             return PrintToString(obj, 0);\n         }\n \n         private string PrintToString(object obj, int nestingLevel)\n         {\n-            //TODO apply configurations\n-            if (obj == null)\n+            if (obj == null)   \n                 return "null" + Environment.NewLine;\n-\n-            var finalTypes = new[]\n-            {\n-                typeof(int), typeof(double), typeof(float), typeof(string),\n-                typeof(DateTime), typeof(TimeSpan)\n-            };\n-            if (finalTypes.Contains(obj.GetType()))\n-                return obj + Environment.NewLine;\n-\n+            propertiesInRecursion.Add(obj);\n+            var type = obj.GetType();\n+            if (excludedTypes.Contains(type))\n+                return FinishWorkWithObjectAndReturnResult(obj, string.Empty);\n+            if (finalTypes.Contains(type))\n+                return FinishWorkWithObjectAndReturnResult(obj,\n+                    ReturnSerializationOFFinalTypeObject(obj));\n             var identation = new string(\'\\t\', nestingLevel + 1);\n             var sb = new StringBuilder();\n-            var type = obj.GetType();\n             sb.AppendLine(type.Name);\n-            foreach (var propertyInfo in type.GetProperties())\n+            if (IsEnumerable(obj))\n+            {\n+                foreach (var element in (IEnumerable) obj)\n+                    sb.Append(identation + PrintToString(element, nestingLevel + 1));\n+            }\n+            else\n             {\n-                sb.Append(identation + propertyInfo.Name + " = " +\n-                          PrintToString(propertyInfo.GetValue(obj),\n-                              nestingLevel + 1));\n+                foreach (var propertyInfo in type.GetProperties())\n+                {\n+         ...
#     'path': 'ObjectPrinting/PrintingConfig.cs',
#     'position': 100,
#     'original_position': 100,
#     'commit_id': '95532334d81cd18d4654ff146952ccc8752b0ac6',
#     'original_commit_id': '95532334d81cd18d4654ff146952ccc8752b0ac6',
#     'user': {'login': 'IvanKogut11',
#      'id': 55024892,
#      'node_id': 'MDQ6VXNlcjU1MDI0ODky',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/55024892?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/IvanKogut11',
#      'html_url': 'https://github.com/IvanKogut11',
#      'followers_url': 'https://api.github.com/users/IvanKogut11/followers',
#      'following_url': 'https://api.github.com/users/IvanKogut11/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/IvanKogut11/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/IvanKogut11/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/IvanKogut11/subscriptions',
#      'organizations_url': 'https://api.github.com/users/IvanKogut11/orgs',
#      'repos_url': 'https://api.github.com/users/IvanKogut11/repos',
#      'events_url': 'https://api.github.com/users/IvanKogut11/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/IvanKogut11/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Ok',
#     'created_at': '2019-11-28T14:53:16Z',
#     'updated_at': '2019-11-28T14:53:16Z',
#     'html_url': 'https://github.com/kontur-courses/fluent-api/pull/61#discussion_r351821233',
#     'pull_request_url': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61',
#     'author_association': 'NONE',
#     '_links': {'self': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/comments/351821233'},
#      'html': {'href': 'https://github.com/kontur-courses/fluent-api/pull/61#discussion_r351821233'},
#      'pull_request': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61'}},
#     'in_reply_to_id': 351738561},
#    'pull_request': {'url': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61',
#     'id': 345302962,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ1MzAyOTYy',
#     'html_url': 'https://github.com/kontur-courses/fluent-api/pull/61',
#     'diff_url': 'https://github.com/kontur-courses/fluent-api/pull/61.diff',
#     'patch_url': 'https://github.com/kontur-courses/fluent-api/pull/61.patch',
#     'issue_url': 'https://api.github.com/repos/kontur-courses/fluent-api/issues/61',
#     'number': 61,
#     'state': 'open',
#     'locked': False,
#     'title': 'Kogut Ivan',
#     'user': {'login': 'IvanKogut11',
#      'id': 55024892,
#      'node_id': 'MDQ6VXNlcjU1MDI0ODky',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/55024892?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/IvanKogut11',
#      'html_url': 'https://github.com/IvanKogut11',
#      'followers_url': 'https://api.github.com/users/IvanKogut11/followers',
#      'following_url': 'https://api.github.com/users/IvanKogut11/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/IvanKogut11/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/IvanKogut11/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/IvanKogut11/subscriptions',
#      'organizations_url': 'https://api.github.com/users/IvanKogut11/orgs',
#      'repos_url': 'https://api.github.com/users/IvanKogut11/repos',
#      'events_url': 'https://api.github.com/users/IvanKogut11/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/IvanKogut11/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Tutor: Sergey Ryabinin',
#     'created_at': '2019-11-25T16:22:22Z',
#     'updated_at': '2019-11-28T14:53:16Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'dda48ee83c5c97e706024819e96511dc6ff87258',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61/commits',
#     'review_comments_url': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61/comments',
#     'review_comment_url': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/kontur-courses/fluent-api/issues/61/comments',
#     'statuses_url': 'https://api.github.com/repos/kontur-courses/fluent-api/statuses/95532334d81cd18d4654ff146952ccc8752b0ac6',
#     'head': {'label': 'IvanKogut11:master',
#      'ref': 'master',
#      'sha': '95532334d81cd18d4654ff146952ccc8752b0ac6',
#      'user': {'login': 'IvanKogut11',
#       'id': 55024892,
#       'node_id': 'MDQ6VXNlcjU1MDI0ODky',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/55024892?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/IvanKogut11',
#       'html_url': 'https://github.com/IvanKogut11',
#       'followers_url': 'https://api.github.com/users/IvanKogut11/followers',
#       'following_url': 'https://api.github.com/users/IvanKogut11/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/IvanKogut11/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/IvanKogut11/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/IvanKogut11/subscriptions',
#       'organizations_url': 'https://api.github.com/users/IvanKogut11/orgs',
#       'repos_url': 'https://api.github.com/users/IvanKogut11/repos',
#       'events_url': 'https://api.github.com/users/IvanKogut11/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/IvanKogut11/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 223590594,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjM1OTA1OTQ=',
#       'name': 'fluent-api',
#       'full_name': 'IvanKogut11/fluent-api',
#       'private': False,
#       'owner': {'login': 'IvanKogut11',
#        'id': 55024892,
#        'node_id': 'MDQ6VXNlcjU1MDI0ODky',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/55024892?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/IvanKogut11',
#        'html_url': 'https://github.com/IvanKogut11',
#        'followers_url': 'https://api.github.com/users/IvanKogut11/followers',
#        'following_url': 'https://api.github.com/users/IvanKogut11/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/IvanKogut11/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/IvanKogut11/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/IvanKogut11/subscriptions',
#        'organizations_url': 'https://api.github.com/users/IvanKogut11/orgs',
#        'repos_url': 'https://api.github.com/users/IvanKogut11/repos',
#        'events_url': 'https://api.github.com/users/IvanKogut11/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/IvanKogut11/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/IvanKogut11/fluent-api',
#       'description': 'Разработка Fluent API',
#       'fork': True,
#       'url': 'https://api.github.com/repos/IvanKogut11/fluent-api',
#       'forks_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/forks',
#       'keys_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/teams',
#       'hooks_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/hooks',
#       'issue_events_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/events',
#       'assignees_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/tags',
#       'blobs_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/languages',
#       'stargazers_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/stargazers',
#       'contributors_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/contributors',
#       'subscribers_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/subscribers',
#       'subscription_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/subscription',
#       'commits_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/merges',
#       'archive_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/downloads',
#       'issues_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/IvanKogut11/fluent-api/deployments',
#       'created_at': '2019-11-23T13:12:07Z',
#       'updated_at': '2019-11-27T14:56:16Z',
#       'pushed_at': '2019-11-27T14:56:13Z',
#       'git_url': 'git://github.com/IvanKogut11/fluent-api.git',
#       'ssh_url': 'git@github.com:IvanKogut11/fluent-api.git',
#       'clone_url': 'https://github.com/IvanKogut11/fluent-api.git',
#       'svn_url': 'https://github.com/IvanKogut11/fluent-api',
#       'homepage': '',
#       'size': 1495,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C#',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'kontur-courses:master',
#      'ref': 'master',
#      'sha': 'cbeab99467dff34cd973eb9f44fd4c72dbcf6fe0',
#      'user': {'login': 'kontur-courses',
#       'id': 19208073,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MjA4MDcz',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/19208073?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kontur-courses',
#       'html_url': 'https://github.com/kontur-courses',
#       'followers_url': 'https://api.github.com/users/kontur-courses/followers',
#       'following_url': 'https://api.github.com/users/kontur-courses/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kontur-courses/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kontur-courses/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kontur-courses/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kontur-courses/orgs',
#       'repos_url': 'https://api.github.com/users/kontur-courses/repos',
#       'events_url': 'https://api.github.com/users/kontur-courses/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kontur-courses/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 62727275,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk2MjcyNzI3NQ==',
#       'name': 'fluent-api',
#       'full_name': 'kontur-courses/fluent-api',
#       'private': False,
#       'owner': {'login': 'kontur-courses',
#        'id': 19208073,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5MjA4MDcz',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/19208073?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kontur-courses',
#        'html_url': 'https://github.com/kontur-courses',
#        'followers_url': 'https://api.github.com/users/kontur-courses/followers',
#        'following_url': 'https://api.github.com/users/kontur-courses/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kontur-courses/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kontur-courses/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kontur-courses/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kontur-courses/orgs',
#        'repos_url': 'https://api.github.com/users/kontur-courses/repos',
#        'events_url': 'https://api.github.com/users/kontur-courses/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kontur-courses/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kontur-courses/fluent-api',
#       'description': 'Разработка Fluent API',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kontur-courses/fluent-api',
#       'forks_url': 'https://api.github.com/repos/kontur-courses/fluent-api/forks',
#       'keys_url': 'https://api.github.com/repos/kontur-courses/fluent-api/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kontur-courses/fluent-api/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kontur-courses/fluent-api/teams',
#       'hooks_url': 'https://api.github.com/repos/kontur-courses/fluent-api/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kontur-courses/fluent-api/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kontur-courses/fluent-api/events',
#       'assignees_url': 'https://api.github.com/repos/kontur-courses/fluent-api/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kontur-courses/fluent-api/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kontur-courses/fluent-api/tags',
#       'blobs_url': 'https://api.github.com/repos/kontur-courses/fluent-api/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kontur-courses/fluent-api/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kontur-courses/fluent-api/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kontur-courses/fluent-api/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kontur-courses/fluent-api/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kontur-courses/fluent-api/languages',
#       'stargazers_url': 'https://api.github.com/repos/kontur-courses/fluent-api/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kontur-courses/fluent-api/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kontur-courses/fluent-api/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kontur-courses/fluent-api/subscription',
#       'commits_url': 'https://api.github.com/repos/kontur-courses/fluent-api/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kontur-courses/fluent-api/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kontur-courses/fluent-api/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kontur-courses/fluent-api/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kontur-courses/fluent-api/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kontur-courses/fluent-api/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kontur-courses/fluent-api/merges',
#       'archive_url': 'https://api.github.com/repos/kontur-courses/fluent-api/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kontur-courses/fluent-api/downloads',
#       'issues_url': 'https://api.github.com/repos/kontur-courses/fluent-api/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kontur-courses/fluent-api/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kontur-courses/fluent-api/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kontur-courses/fluent-api/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kontur-courses/fluent-api/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kontur-courses/fluent-api/deployments',
#       'created_at': '2016-07-06T14:27:15Z',
#       'updated_at': '2019-11-21T08:14:15Z',
#       'pushed_at': '2019-11-28T14:48:20Z',
#       'git_url': 'git://github.com/kontur-courses/fluent-api.git',
#       'ssh_url': 'git@github.com:kontur-courses/fluent-api.git',
#       'clone_url': 'https://github.com/kontur-courses/fluent-api.git',
#       'svn_url': 'https://github.com/kontur-courses/fluent-api',
#       'homepage': None,
#       'size': 1484,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 119,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 72,
#       'license': None,
#       'forks': 119,
#       'open_issues': 72,
#       'watchers': 6,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61'},
#      'html': {'href': 'https://github.com/kontur-courses/fluent-api/pull/61'},
#      'issue': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/issues/61'},
#      'comments': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/issues/61/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/pulls/61/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/kontur-courses/fluent-api/statuses/95532334d81cd18d4654ff146952ccc8752b0ac6'}},
#     'author_association': 'NONE'}},
#   'public': True,
#   'created_at': '2019-11-28T14:53:16Z',
#   'org': {'id': 19208073,
#    'login': 'kontur-courses',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kontur-courses',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19208073?'}},
#  {'id': '10969929802',
#   'type': 'PushEvent',
#   'actor': {'id': 23419905,
#    'login': 'frankfg94',
#    'display_login': 'frankfg94',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/frankfg94',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23419905?'},
#   'repo': {'id': 223729566,
#    'name': 'frankfg94/WebApiRest',
#    'url': 'https://api.github.com/repos/frankfg94/WebApiRest'},
#   'payload': {'push_id': 4332506478,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7bdf779dcc06b9212a771a7cd71f76c7aa6b0ffd',
#    'before': 'b5267e74e408310d933c13434ec45c65cfecf4c9',
#    'commits': [{'sha': 'f0426fb616cc0376643eaf5576db5d2588cc40ad',
#      'author': {'email': 'nicolas.guibert@efrei.net', 'name': 'Nicolas'},
#      'message': 'Add search by keyword function',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/frankfg94/WebApiRest/commits/f0426fb616cc0376643eaf5576db5d2588cc40ad'},
#     {'sha': 'b797dcdccb3370ba3a5b821a826326aebfed4a5d',
#      'author': {'email': 'francois.gillioen@efrei.net', 'name': 'François'},
#      'message': "Merge branch 'master' into keyWord-search",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/frankfg94/WebApiRest/commits/b797dcdccb3370ba3a5b821a826326aebfed4a5d'},
#     {'sha': '7bdf779dcc06b9212a771a7cd71f76c7aa6b0ffd',
#      'author': {'email': 'francois.gillioen@efrei.net', 'name': 'François'},
#      'message': 'Merge pull request #3 from frankfg94/keyWord-search\n\nMerge accepté, user et mdp db changés',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/frankfg94/WebApiRest/commits/7bdf779dcc06b9212a771a7cd71f76c7aa6b0ffd'}]},
#   'public': True,
#   'created_at': '2019-11-28T14:53:16Z'},
#  {'id': '10969929809',
#   'type': 'CreateEvent',
#   'actor': {'id': 46643361,
#    'login': 'peasecode',
#    'display_login': 'peasecode',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peasecode',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46643361?'},
#   'repo': {'id': 224675375,
#    'name': 'peasecode/springboot',
#    'url': 'https://api.github.com/repos/peasecode/springboot'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T14:53:16Z'},
#  {'id': '10969929799',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 23255526,
#    'login': 'Tornaco',
#    'display_login': 'Tornaco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tornaco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23255526?'},
#   'repo': {'id': 212005520,
#    'name': 'Tornaco/Thanox',
#    'url': 'https://api.github.com/repos/Tornaco/Thanox'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Tornaco/Thanox/issues/3',
#     'repository_url': 'https://api.github.com/repos/Tornaco/Thanox',
#     'labels_url': 'https://api.github.com/repos/Tornaco/Thanox/issues/3/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Tornaco/Thanox/issues/3/comments',
#     'events_url': 'https://api.github.com/repos/Tornaco/Thanox/issues/3/events',
#     'html_url': 'https://github.com/Tornaco/Thanox/issues/3',
#     'id': 512509139,
#     'node_id': 'MDU6SXNzdWU1MTI1MDkxMzk=',
#     'number': 3,
#     'title': '自动重启。rec删除后恢复正常。',
#     'user': {'login': 'mymine',
#      'id': 2943365,
#      'node_id': 'MDQ6VXNlcjI5NDMzNjU=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/2943365?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mymine',
#      'html_url': 'https://github.com/mymine',
#      'followers_url': 'https://api.github.com/users/mymine/followers',
#      'following_url': 'https://api.github.com/users/mymine/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mymine/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mymine/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mymine/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mymine/orgs',
#      'repos_url': 'https://api.github.com/users/mymine/repos',
#      'events_url': 'https://api.github.com/users/mymine/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mymine/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1587980066,
#       'node_id': 'MDU6TGFiZWwxNTg3OTgwMDY2',
#       'url': 'https://api.github.com/repos/Tornaco/Thanox/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'Tornaco',
#      'id': 23255526,
#      'node_id': 'MDQ6VXNlcjIzMjU1NTI2',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/23255526?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Tornaco',
#      'html_url': 'https://github.com/Tornaco',
#      'followers_url': 'https://api.github.com/users/Tornaco/followers',
#      'following_url': 'https://api.github.com/users/Tornaco/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Tornaco/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Tornaco/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Tornaco/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Tornaco/orgs',
#      'repos_url': 'https://api.github.com/users/Tornaco/repos',
#      'events_url': 'https://api.github.com/users/Tornaco/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Tornaco/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'Tornaco',
#       'id': 23255526,
#       'node_id': 'MDQ6VXNlcjIzMjU1NTI2',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/23255526?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Tornaco',
#       'html_url': 'https://github.com/Tornaco',
#       'followers_url': 'https://api.github.com/users/Tornaco/followers',
#       'following_url': 'https://api.github.com/users/Tornaco/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Tornaco/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Tornaco/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Tornaco/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Tornaco/orgs',
#       'repos_url': 'https://api.github.com/users/Tornaco/repos',
#       'events_url': 'https://api.github.com/users/Tornaco/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Tornaco/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/Tornaco/Thanox/milestones/1',
#      'html_url': 'https://github.com/Tornaco/Thanox/milestone/1',
#      'labels_url': 'https://api.github.com/repos/Tornaco/Thanox/milestones/1/labels',
#      'id': 4746097,
#      'node_id': 'MDk6TWlsZXN0b25lNDc0NjA5Nw==',
#      'number': 1,
#      'title': 'Development',
#      'description': None,
#      'creator': {'login': 'Tornaco',
#       'id': 23255526,
#       'node_id': 'MDQ6VXNlcjIzMjU1NTI2',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/23255526?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Tornaco',
#       'html_url': 'https://github.com/Tornaco',
#       'followers_url': 'https://api.github.com/users/Tornaco/followers',
#       'following_url': 'https://api.github.com/users/Tornaco/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Tornaco/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Tornaco/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Tornaco/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Tornaco/orgs',
#       'repos_url': 'https://api.github.com/users/Tornaco/repos',
#       'events_url': 'https://api.github.com/users/Tornaco/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Tornaco/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 7,
#      'closed_issues': 5,
#      'state': 'open',
#      'created_at': '2019-10-12T13:22:04Z',
#      'updated_at': '2019-11-27T09:41:56Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 15,
#     'created_at': '2019-10-25T13:12:58Z',
#     'updated_at': '2019-11-28T14:53:16Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '@Tornaco\r\n自动重启。rec删除后恢复正常。\r\n软件删掉了 @Tornaco \r\n<img>http://qiniu.img.hu60.cn/file-hash-jpg-4493a9a228d11e1647a6c31fd3214d4c81112.jpg</img>\r\n日志http://qiniu.img.hu60.cn/file-hash-zip-776503c5ec14eae1213e2514c24c9cae15454.zip'},
#    'comment': {'url': 'https://api.github.com/repos/Tornaco/Thanox/issues/comments/559522917',
#     'html_url': 'https://github.com/Tornaco/Thanox/issues/3#issuecomment-559522917',
#     'issue_url': 'https://api.github.com/repos/Tornaco/Thanox/issues/3',
#     'id': 559522917,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTUyMjkxNw==',
#     'user': {'login': 'Tornaco',
#      'id': 23255526,
#      'node_id': 'MDQ6VXNlcjIzMjU1NTI2',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/23255526?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Tornaco',
#      'html_url': 'https://github.com/Tornaco',
#      'followers_url': 'https://api.github.com/users/Tornaco/followers',
#      'following_url': 'https://api.github.com/users/Tornaco/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Tornaco/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Tornaco/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Tornaco/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Tornaco/orgs',
#      'repos_url': 'https://api.github.com/users/Tornaco/repos',
#      'events_url': 'https://api.github.com/users/Tornaco/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Tornaco/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T14:53:16Z',
#     'updated_at': '2019-11-28T14:53:16Z',
#     'author_association': 'OWNER',
#     'body': '➜  Thanox git:(master) ✗ pwd\r\n/Users/tornaco/Documents/Workspace/Android/Thanox'}},
#   'public': True,
#   'created_at': '2019-11-28T14:53:16Z'},
#  {'id': '10969929785',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 224663511,
#    'name': 'alvinz97/Next-Auction',
#    'url': 'https://api.github.com/repos/alvinz97/Next-Auction'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/alvinz97/Next-Auction/pulls/3',
#     'id': 346737546,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NzM3NTQ2',
#     'html_url': 'https://github.com/alvinz97/Next-Auction/pull/3',
#     'diff_url': 'https://github.com/alvinz97/Next-Auction/pull/3.diff',
#     'patch_url': 'https://github.com/alvinz97/Next-Auction/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/alvinz97/Next-Auction/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump lodash from 4.17.11 to 4.17.15 in /WebContent',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': "Bumps [lodash](https://github.com/lodash/lodash) from 4.17.11 to 4.17.15.\n<details>\n<summary>Commits</summary>\n\n- [`ddfd9b1`](https://github.com/lodash/lodash/commit/ddfd9b11a0126db2302cb70ec9973b66baec0975) Bump to v4.17.15.\n- [`b185fce`](https://github.com/lodash/lodash/commit/b185fcee26b2133bd071f4aaca14b455c2ed1008) Rebuild lodash and docs.\n- [`be87d30`](https://github.com/lodash/lodash/commit/be87d303941222b97c482755afc0f4a77ce46c30) Bump to v4.17.14.\n- [`a6fe6b1`](https://github.com/lodash/lodash/commit/a6fe6b1e174fd02b5e60eb2664405f4c1262c300) Rebuild lodash and docs.\n- [`e371828`](https://github.com/lodash/lodash/commit/e37182845f16715a0d1c391c8662d83c55609cee) Bump to v4.17.13.\n- [`357e899`](https://github.com/lodash/lodash/commit/357e899e685872b4af5403ecc4b2a928f961ae63) Rebuild lodash and docs.\n- [`fd9a062`](https://github.com/lodash/lodash/commit/fd9a062d57646450b61f74029315abd4cc834b08) Bump to v4.17.12.\n- [`e77d681`](https://github.com/lodash/lodash/commit/e77d68121ff00ba86b53eed5893d35adfe94c9dd) Rebuild lodash and docs.\n- [`629d186`](https://github.com/lodash/lodash/commit/629d1865793182cd967196716f4beff223aa4a91) Update OpenJS references.\n- [`2406eac`](https://github.com/lodash/lodash/commit/2406eac542b2a1282be8d812a6d8a45433ade80a) Fix minified build.\n- Additional commits viewable in [compare view](https://github.com/lodash/lodash/compare/4.17.11...4.17.15)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=lodash&package-manager=npm_and_yarn&previous-version=4.17.11&new-version=4.17.15)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don't alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/alvinz97/Next-Auction/network/alerts).\n\n</details>",
#     'created_at': '2019-11-28T14:53:15Z',
#     'updated_at': '2019-11-28T14:53:15Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/alvinz97/Next-Auction/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/alvinz97/Next-Auction/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/alvinz97/Next-Auction/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/alvinz97/Next-Auction/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/alvinz97/Next-Auction/statuses/09e75b1465e78816cf145245d65baddcad71848f',
#     'head': {'label': 'alvinz97:dependabot/npm_and_yarn/WebContent/lodash-4.17.15',
#      'ref': 'dependabot/npm_and_yarn/WebContent/lodash-4.17.15',
#      'sha': '09e75b1465e78816cf145245d65baddcad71848f',
#      'user': {'login': 'alvinz97',
#       'id': 48641298,
#       'node_id': 'MDQ6VXNlcjQ4NjQxMjk4',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/48641298?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/alvinz97',
#       'html_url': 'https://github.com/alvinz97',
#       'followers_url': 'https://api.github.com/users/alvinz97/followers',
#       'following_url': 'https://api.github.com/users/alvinz97/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/alvinz97/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/alvinz97/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/alvinz97/subscriptions',
#       'organizations_url': 'https://api.github.com/users/alvinz97/orgs',
#       'repos_url': 'https://api.github.com/users/alvinz97/repos',
#       'events_url': 'https://api.github.com/users/alvinz97/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/alvinz97/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224663511,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ2NjM1MTE=',
#       'name': 'Next-Auction',
#       'full_name': 'alvinz97/Next-Auction',
#       'private': False,
#       'owner': {'login': 'alvinz97',
#        'id': 48641298,
#        'node_id': 'MDQ6VXNlcjQ4NjQxMjk4',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/48641298?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/alvinz97',
#        'html_url': 'https://github.com/alvinz97',
#        'followers_url': 'https://api.github.com/users/alvinz97/followers',
#        'following_url': 'https://api.github.com/users/alvinz97/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/alvinz97/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/alvinz97/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/alvinz97/subscriptions',
#        'organizations_url': 'https://api.github.com/users/alvinz97/orgs',
#        'repos_url': 'https://api.github.com/users/alvinz97/repos',
#        'events_url': 'https://api.github.com/users/alvinz97/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/alvinz97/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/alvinz97/Next-Auction',
#       'description': 'Online Bidding / Auction System',
#       'fork': False,
#       'url': 'https://api.github.com/repos/alvinz97/Next-Auction',
#       'forks_url': 'https://api.github.com/repos/alvinz97/Next-Auction/forks',
#       'keys_url': 'https://api.github.com/repos/alvinz97/Next-Auction/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/alvinz97/Next-Auction/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/alvinz97/Next-Auction/teams',
#       'hooks_url': 'https://api.github.com/repos/alvinz97/Next-Auction/hooks',
#       'issue_events_url': 'https://api.github.com/repos/alvinz97/Next-Auction/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/alvinz97/Next-Auction/events',
#       'assignees_url': 'https://api.github.com/repos/alvinz97/Next-Auction/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/alvinz97/Next-Auction/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/alvinz97/Next-Auction/tags',
#       'blobs_url': 'https://api.github.com/repos/alvinz97/Next-Auction/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/alvinz97/Next-Auction/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/alvinz97/Next-Auction/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/alvinz97/Next-Auction/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/alvinz97/Next-Auction/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/alvinz97/Next-Auction/languages',
#       'stargazers_url': 'https://api.github.com/repos/alvinz97/Next-Auction/stargazers',
#       'contributors_url': 'https://api.github.com/repos/alvinz97/Next-Auction/contributors',
#       'subscribers_url': 'https://api.github.com/repos/alvinz97/Next-Auction/subscribers',
#       'subscription_url': 'https://api.github.com/repos/alvinz97/Next-Auction/subscription',
#       'commits_url': 'https://api.github.com/repos/alvinz97/Next-Auction/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/alvinz97/Next-Auction/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/alvinz97/Next-Auction/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/alvinz97/Next-Auction/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/alvinz97/Next-Auction/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/alvinz97/Next-Auction/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/alvinz97/Next-Auction/merges',
#       'archive_url': 'https://api.github.com/repos/alvinz97/Next-Auction/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/alvinz97/Next-Auction/downloads',
#       'issues_url': 'https://api.github.com/repos/alvinz97/Next-Auction/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/alvinz97/Next-Auction/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/alvinz97/Next-Auction/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/alvinz97/Next-Auction/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/alvinz97/Next-Auction/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/alvinz97/Next-Auction/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/alvinz97/Next-Auction/deployments',
#       'created_at': '2019-11-28T13:50:43Z',
#       'updated_at': '2019-11-28T14:51:52Z',
#       'pushed_at': '2019-11-28T14:53:15Z',
#       'git_url': 'git://github.com/alvinz97/Next-Auction.git',
#       'ssh_url': 'git@github.com:alvinz97/Next-Auction.git',
#       'clone_url': 'https://github.com/alvinz97/Next-Auction.git',
#       'svn_url': 'https://github.com/alvinz97/Next-Auction',
#       'homepage': None,
# ...
#     'comments': 6,
#     'created_at': '2019-11-18T00:16:49Z',
#     'updated_at': '2019-11-28T14:53:15Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'pull_request': {'url': 'https://api.github.com/repos/PyCQA/prospector/pulls/354',
#      'html_url': 'https://github.com/PyCQA/prospector/pull/354',
#      'diff_url': 'https://github.com/PyCQA/prospector/pull/354.diff',
#      'patch_url': 'https://github.com/PyCQA/prospector/pull/354.patch'},
#     'body': '- Update pyflakes support to < 2.1.0\r\n- Add bandit support\r\n- Ignore `__pycache__` and `node_modules`\r\n- Fix compatibility issues with mypy >= 0.730'},
#    'comment': {'url': 'https://api.github.com/repos/PyCQA/prospector/issues/comments/559522914',
#     'html_url': 'https://github.com/PyCQA/prospector/pull/354#issuecomment-559522914',
#     'issue_url': 'https://api.github.com/repos/PyCQA/prospector/issues/354',
#     'id': 559522914,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTUyMjkxNA==',
#     'user': {'login': 'Dunedan',
#      'id': 1735355,
#      'node_id': 'MDQ6VXNlcjE3MzUzNTU=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/1735355?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Dunedan',
#      'html_url': 'https://github.com/Dunedan',
#      'followers_url': 'https://api.github.com/users/Dunedan/followers',
#      'following_url': 'https://api.github.com/users/Dunedan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Dunedan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Dunedan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Dunedan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Dunedan/orgs',
#      'repos_url': 'https://api.github.com/users/Dunedan/repos',
#      'events_url': 'https://api.github.com/users/Dunedan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Dunedan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T14:53:15Z',
#     'updated_at': '2019-11-28T14:53:15Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "Thx. I wasn't aware this version is available on PyPI and was looking for a tag in the repo."}},
#   'public': True,
#   'created_at': '2019-11-28T14:53:15Z',
#   'org': {'id': 8749848,
#    'login': 'PyCQA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PyCQA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8749848?'}},
#  {'id': '10969929713',
#   'type': 'PushEvent',
#   'actor': {'id': 33124528,
#    'login': '0may',
#    'display_login': '0may',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/0may',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33124528?'},
#   'repo': {'id': 195191589,
#    'name': '0may/RaspiHowtos',
#    'url': 'https://api.github.com/repos/0may/RaspiHowtos'},
#   'payload': {'push_id': 4332506433,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c10fe8a5f9b0f37855ccf78d640168e4ce541452',
#    'before': 'd5fe7a193b73bb400b9f238fe9d887f591c8e668',
#    'commits': [{'sha': 'c10fe8a5f9b0f37855ccf78d640168e4ce541452',
#      'author': {'email': 'mayer@adbk-nuernberg.de', 'name': 'Oliver Mayer'},
#      'message': 'wiring layout added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/0may/RaspiHowtos/commits/c10fe8a5f9b0f37855ccf78d640168e4ce541452'}]},
#   'public': True,
#   'created_at': '2019-11-28T14:53:15Z'},
#  {'id': '10969929729',
#   'type': 'IssuesEvent',
#   'actor': {'id': 1148549,
#    'login': 'edolstra',
#    'display_login': 'edolstra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edolstra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1148549?'},
#   'repo': {'id': 3386088,
#    'name': 'NixOS/nix',
#    'url': 'https://api.github.com/repos/NixOS/nix'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/NixOS/nix/issues/726',
#     'repository_url': 'https://api.github.com/repos/NixOS/nix',
#     'labels_url': 'https://api.github.com/repos/NixOS/nix/issues/726/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/NixOS/nix/issues/726/comments',
#     'events_url': 'https://api.github.com/repos/NixOS/nix/issues/726/events',
#     'html_url': 'https://github.com/NixOS/nix/issues/726',
#     'id': 119846094,
#     'node_id': 'MDU6SXNzdWUxMTk4NDYwOTQ=',
#     'number': 726,
#     'title': 'nix-shell -p is too magical',
#     'user': {'login': 'copumpkin',
#      'id': 2623,
#      'node_id': 'MDQ6VXNlcjI2MjM=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/2623?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/copumpkin',
#      'html_url': 'https://github.com/copumpkin',
#      'followers_url': 'https://api.github.com/users/copumpkin/followers',
#      'following_url': 'https://api.github.com/users/copumpkin/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/copumpkin/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/copumpkin/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/copumpkin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/copumpkin/orgs',
#      'repos_url': 'https://api.github.com/users/copumpkin/repos',
#      'events_url': 'https://api.github.com/users/copumpkin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/copumpkin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 886485313,
#       'node_id': 'MDU6TGFiZWw4ODY0ODUzMTM=',
#       'url': 'https://api.github.com/repos/NixOS/nix/labels/backlog',
#       'name': 'backlog',
#       'color': 'fbca04',
#       'default': False,
#       'description': 'backlog of issues predating triage rotation'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'peti',
#      'id': 28323,
#      'node_id': 'MDQ6VXNlcjI4MzIz',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/28323?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/peti',
#      'html_url': 'https://github.com/peti',
#      'followers_url': 'https://api.github.com/users/peti/followers',
#      'following_url': 'https://api.github.com/users/peti/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/peti/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/peti/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/peti/subscriptions',
#      'organizations_url': 'https://api.github.com/users/peti/orgs',
#      'repos_url': 'https://api.github.com/users/peti/repos',
#      'events_url': 'https://api.github.com/users/peti/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/peti/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'peti',
#       'id': 28323,
#       'node_id': 'MDQ6VXNlcjI4MzIz',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/28323?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/peti',
#       'html_url': 'https://github.com/peti',
#       'followers_url': 'https://api.github.com/users/peti/followers',
#       'following_url': 'https://api.github.com/users/peti/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/peti/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/peti/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/peti/subscriptions',
#       'organizations_url': 'https://api.github.com/users/peti/orgs',
#       'repos_url': 'https://api.github.com/users/peti/repos',
#       'events_url': 'https://api.github.com/users/peti/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/peti/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2015-12-02T01:22:14Z',
#     'updated_at': '2019-11-28T14:53:15Z',
#     'closed_at': '2019-11-28T14:53:15Z',
#     'author_association': 'MEMBER',
#     'body': 'With `nix-shell -A`, I can pass it a .nix file to run expressions against, but I can\'t emulate that behavior easily with `nix-shell -p`. For example, `nix-shell -p foo` will install `foo` in my shell. If I run `nix-shell \'<nixpkgs>\' -A foo`, that doesn\'t give me the same thing. If I want something similar, @puffnfresh on IRC suggested this nasty thing:\n\n```\nnix-shell -E \'with import <nixpkgs> { }; runCommand "ignored" { buildInputs = [ (import ./.).foo ]; } ""\'\n```\n\nwhich doesn\'t seem great. Can we have an easy way to get behavior like `-p` without relying on `NIX_PATH` voodoo or the incantation above?\n'}},
#   'public': True,
#   'created_at': '2019-11-28T14:53:15Z',
#   'org': {'id': 487568,
#    'login': 'NixOS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NixOS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/487568?'}},
#  {'id': '10969929711',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 6840312,
#    'login': 'jschmid1',
#    'display_login': 'jschmid1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jschmid1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6840312?'},
#   'repo': {'id': 66941942,
#    'name': 'SUSE/DeepSea',
#    'url': 'https://api.github.com/repos/SUSE/DeepSea'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/SUSE/DeepSea/issues/1807',
#     'repository_url': 'https://api.github.com/repos/SUSE/DeepSea',
#     'labels_url': 'https://api.github.com/repos/SUSE/DeepSea/issues/1807/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/SUSE/DeepSea/issues/1807/comments',
#     'events_url': 'https://api.github.com/repos/SUSE/DeepSea/issues/1807/events',
#     'html_url': 'https://github.com/SUSE/DeepSea/pull/1807',
#     'id': 529953036,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NzM0MzM5',
#     'number': 1807,
#     'title': 'osd/replace: only access metadata if present',
#     'user': {'login': 'jschmid1',
#      'id': 6840312,
#      'node_id': 'MDQ6VXNlcjY4NDAzMTI=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/6840312?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jschmid1',
#      'html_url': 'https://github.com/jschmid1',
#      'followers_url': 'https://api.github.com/users/jschmid1/followers',
#      'following_url': 'https://api.github.com/users/jschmid1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jschmid1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jschmid1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jschmid1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jschmid1/orgs',
#      'repos_url': 'https://api.github.com/users/jschmid1/repos',
#      'events_url': 'https://api.github.com/users/jschmid1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jschmid1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 730559433,
#       'node_id': 'MDU6TGFiZWw3MzA1NTk0MzM=',
#       'url': 'https://api.github.com/repos/SUSE/DeepSea/labels/needs-backport',
#       'name': 'needs-backport',
#       'color': '9fed93',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-11-28T14:45:43Z',
#     'updated_at': '2019-11-28T14:53:15Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'pull_request': {'url': 'https://api.github.com/repos/SUSE/DeepSea/pulls/1807',
#      'html_url': 'https://github.com/SUSE/DeepSea/pull/1807',
#      'diff_url': 'https://github.com/SUSE/DeepSea/pull/1807.diff',
#      'patch_url': 'https://github.com/SUSE/DeepSea/pull/1807.patch'},
#     'body': 'When a OSD is not actively deployed anymore\r\nbut is still present in the crushmap you want to be\r\nable to replace it.\r\nThis patch extends the condition for such a case.\r\n\r\nsuse_internal: bsc#1157469\r\nSigned-off-by: Joshua Schmid <jschmid@suse.de>\r\n\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/SUSE/DeepSea/issues/comments/559522913',
#     'html_url': 'https://github.com/SUSE/DeepSea/pull/1807#issuecomment-559522913',
#     'issue_url': 'https://api.github.com/repos/SUSE/DeepSea/issues/1807',
#     'id': 559522913,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTUyMjkxMw==',
#     'user': {'login': 'jschmid1',
#      'id': 6840312,
#      'node_id': 'MDQ6VXNlcjY4NDAzMTI=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/6840312?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jschmid1',
#      'html_url': 'https://github.com/jschmid1',
#      'followers_url': 'https://api.github.com/users/jschmid1/followers',
#      'following_url': 'https://api.github.com/users/jschmid1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jschmid1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jschmid1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jschmid1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jschmid1/orgs',
#      'repos_url': 'https://api.github.com/users/jschmid1/repos',
#      'events_url': 'https://api.github.com/users/jschmid1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jschmid1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T14:53:15Z',
#     'updated_at': '2019-11-28T14:53:15Z',
#     'author_association': 'MEMBER',
#     'body': '@susebot run teuthology'}},
#   'public': True,
#   'created_at': '2019-11-28T14:53:15Z',
#   'org': {'id': 1067733,
#    'login': 'SUSE',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SUSE',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1067733?'}},
#  {'id': '10969929707',
#   'type': 'CreateEvent',
#   'actor': {'id': 27616697,
#    'login': 'RajarshiRiju',
#    'display_login': 'RajarshiRiju',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RajarshiRiju',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27616697?'},
#   'repo': {'id': 224675192,
#    'name': 'RajarshiRiju/CS7NS1-Project4-SimulateBANprotocol',
#    'url': 'https://api.github.com/repos/RajarshiRiju/CS7NS1-Project4-SimulateBANprotocol'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T14:53:15Z'},
#  {'id': '10969929699',
#   'type': 'PushEvent',
#   'actor': {'id': 57986493,
#    'login': 'myxy66',
#    'display_login': 'myxy66',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/myxy66',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57986493?'},
#   'repo': {'id': 223889279,
#    'name': 'zking-shopping/shop',
#    'url': 'https://api.github.com/repos/zking-shopping/shop'},
#   'payload': {'push_id': 4332506421,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '23fd8bcf9fa17714ac795d6d12ec1fd1fd7bc876',
#    'before': '53f1e35798e891904c9589fa94c8d88765c50d65',
#    'commits': [{'sha': 'de94cfe83efa0971072e71b30173ca26112aed8e',
#      'author': {'email': 'xy@windows10.microdone.cn', 'name': 'xy'},
#      'message': 'xy对actionservlet做了更新',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zking-shopping/shop/commits/de94cfe83efa0971072e71b30173ca26112aed8e'},
#     {'sha': '23fd8bcf9fa17714ac795d6d12ec1fd1fd7bc876',
#      'author': {'email': 'xy@windows10.microdone.cn', 'name': 'xy'},
#      'message': 'xy对actionservlet作了更新',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zking-shopping/shop/commits/23fd8bcf9fa17714ac795d6d12ec1fd1fd7bc876'}]},
#   'public': True,
#   'created_at': '2019-11-28T14:53:15Z',
#   'org': {'id': 58014368,
#    'login': 'zking-shopping',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zking-shopping',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58014368?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
# Out:
# '\nYour Code\n'
